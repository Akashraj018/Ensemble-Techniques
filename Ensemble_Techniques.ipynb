# %% [markdown]
# 1.  Can we use Bagging for regression problems?
#
# Yes, you can use Bagging for regression problems.
# Bagging (Bootstrap Aggregating) reduces variance by training multiple regression models on different bootstrap samples and then averaging their predictions. Averaging works naturally for continuous outputs, which is why bagging fits regression tasks well.
#
# Common Bagging-Based Regression Models
# Bagging Regressor (generic, can wrap any regressor)
# Random Forest Regressor (bagging + random feature selection)
# Extra Trees Regressor
# Bagging improves performance especially when the base regressor has high variance, such as decision trees.

# %% [markdown]
# 2.  What is the difference between multiple model training and single model training ?
#
# The difference between single model training and multiple model training is mainly about how many models you train and how they use data, compute, and predictions
#
# Single Model Training -
# You train one model on the entire dataset
# Characteristics
# Only one set of parameters is learned.
# Prediction is made by that single model.
# Faster training and inference.
# Easier to interpret.
# More prone to overfitting or underfitting, depending on model complexity.
#
# Multiple Model Training-
# Uses multiple models to make a final decision:
# . Averaging (regression)
# . Voting (classification)
# . Weighted combination (boosting, stacking)
# More computation required.
# Higher accuracy and stability.
# Reduces variance and overfitting.

# %% [markdown]
# 3.  Explain the concept of feature randomness in Random Forest
#
# Feature randomness in a Random Forest refers to the deliberate random selection of a subset of features at each split of every decision tree.This is one of the key reasons Random Forests reduce overfitting and outperform single decision trees.
#
# Feature Randomness -In a Decision Tree, each split is chosen from all features.In a Random Forest, at each split:
# In a Decision Tree, each split is chosen from all features.
# In a Random Forest, at each split:
# This randomness ensures trees become more diverse and less correlated.
#
# Feature Randomness Uses.
# Reduces correlation between trees
# Reduces overfitting
# Improves performance on high-dimensional data.

# %% [markdown]
# 4. What is OOB (Out-of-Bag) Score?
#
# The OOB (Out-of-Bag) score is an internal performance estimate used in Bagging and Random Forests without needing a separate validation set.when training a Random Forest, each tree is trained on a bootstrap sample—a random sample taken with replacement from the original dataset.Because sampling is done with replacement:
# On average, about 63% of the data is selected for training each tree.
# The remaining ~37% of data, which is not selected, is called the Out-of-Bag (OOB) samples.These OOB samples act like a built-in validation set for that specific tree.

# %% [markdown]
# 5. How can you measure the importance of features in a Random Forest model?
# we can measure feature importance in a Random Forest using several methods. Random Forests naturally provide importance scores because they contain many decision trees and evaluate how much each feature contributes to reducing impurity or improving prediction accuracy.
# Below are the methods to measure feature importance
# . Gini Importance
# . Permutation Importance
# . Out-of-Bag (OOB) Permutation Importance
# . SHAP Values (SHapley Additive exPlanations)

# %% [markdown]
# 6.  Explain the working principle of a Bagging Classifier?
#
# A Bagging Classifier (Bootstrap Aggregating Classifier) is an ensemble method that reduces variance and improves accuracy by training multiple models on different random subsets of the data and then combining their predictions.
# Working Principle of a Bagging Classifier
# Bootstrap Sampling
# Train a Separate Classifier on Each Subset
# Make Predictions Using All Models
# Combine Predictions (Majority Voting)

# %% [markdown]
# 7. How do you evaluate a Bagging Classifier’s performance?
#
# we can evaluate a Bagging Classifier’s performance using the same methods used for other classification models, but Bagging also provides some built-in evaluation tools such as Out-of-Bag (OOB) score.
# Below are all the commonly used evaluation techniques.
# Train–Test Split Evaluation
# Cross-Validation (K-Fold CV)
# Out-of-Bag (OOB) Score
# Evaluation Metrics (Classification Metrics)
# Compare With Baseline Models

# %% [markdown]
# 8. How does a Bagging Regressor work?
#
# A Bagging Regressor works by combining the predictions of multiple regression models trained on different random subsets of the data. The goal is to reduce variance, improve stability, and prevent overfitting—especially when using high-variance models like decision trees.
#
# Here is the step-by-step working principle:
# 1. Bootstrap Sampling (Random Subsets of Data)
# 2. Train a Separate Regression Model on Each Sample
# 3. Make Predictions from All Models
# 4. Aggregate Predictions by Averaging

# %% [markdown]
# 9.  What is the main advantage of ensemble techniques ?
#
# The main advantage of ensemble techniques is that they combine multiple models to produce a stronger, more accurate, and more stable overall model than any single model could achieve.
# - They reduce variance, bias, or both — leading to better generalization
# - Higher prediction accuracy
# - Better generalization
# - More stable predictions
# - Flexibility
# - Handle complex relationships

# %% [markdown]
# 10. What is the main challenge of ensemble method ?
#
# The main challenge of ensemble methods is that they can be computationally expensive and complex, both in terms of training and interpretation.
# While ensembles improve accuracy and stability, they also introduce several practical challenges.
# Key Challenges of Ensemble Methods
# 1. Increased Computational Cost
# 2. Reduced Interpretability
# 3. Risk of Diminishing Returns
# 4. Complexity in Tuning
# 5. Potential Overfitting (in some cases)

# %% [markdown]
# 11. Explain the key idea behind ensemble techniques?
#
# Combine multiple models to produce a stronger, more accurate, and more robust model than any individual model.
#
# Instead of relying on a single model, ensembles leverage the “wisdom of the crowd”: multiple models vote or average their predictions, which helps reduce errors and improve generalization.
# it work like -Diversity of Models , Aggregation of Predictions and Error Reduction ,

# %% [markdown]
# 12. What is a Random Forest Classifier ?
#
# A Random Forest Classifier is an ensemble learning method used for classification tasks that combines multiple decision trees to improve accuracy, stability, and generalization. It is essentially an extension of bagging (bootstrap aggregating) with an additional layer of feature randomness.
# Key Features
# Multiple Decision Trees
# Bootstrap Sampling
# Random Feature Selection
# Aggregation by Voting

# %% [markdown]
# 13. What are the main types of ensemble techniques ?
#
# The main types of ensemble techniques are based on how multiple models are combined and how they are trained. There are three widely recognized categories:Bagging (Bootstrap Aggregating) , Boosting , Stacking (Stacked Generalization),

# %% [markdown]
# 14.  What is ensemble learning in machine learning ?
#
# Ensemble learning in machine learning is a technique that combines multiple models to produce a stronger and more accurate predictive model than any single model on its own.
# The central idea is that “multiple weak learners working together can form a strong learner”, reducing errors and improving generalization.
#
# we use Ensemble Learning for Higher accuracy ,Better generalization ,
# Stability , Flexibility

# %% [markdown]
# 15.  When should we avoid using ensemble methods?
#
# While ensemble methods are powerful, there are situations where using them may not be ideal. Here are the main scenarios to avoid or reconsider ensemble methods:
# When to Avoid Ensemble Methods
# 1. Small Datasets
# 2. Need for Interpretability
# 3. Limited Computational Resources
# 4. Marginal Performance Gains
# 5. Noisy Data

# %% [markdown]
# 16.  How does Bagging help in reducing overfitting?
#
# Bagging (Bootstrap Aggregating) helps in reducing overfitting by combining multiple models trained on different subsets of the data, which reduces variance without increasing bias. Let’s break this down carefully
# Bagging Reduces Overfitting with theses
# 1. High-Variance Models Are Prone to Overfitting
# 2. Bootstrap Sampling Creates Diverse Training Sets
# 3. Aggregation Reduces Variance
# 4. Out-of-Bag Evaluation

# %% [markdown]
# 17.  Why is Random Forest better than a single Decision Tree ?
#
# Random Forest is generally better than a single Decision Tree because it reduces overfitting, increases stability, and improves predictive accuracy by combining many trees instead of relying on one.

# %% [markdown]
# 18.  What is the role of bootstrap sampling in Bagging ?
#
# The role of bootstrap sampling in Bagging is central—it’s the reason Bagging can reduce variance and prevent overfitting
# Bootstrap sampling is a method of creating random subsets of the training data with replacement.Each subset is called a bootstrap sample.Role of Bootstrap Sampling in Bagging 1.Creates Diversity Among Models 2.Reduces Variance 3.Enables Out-of-Bag Evaluation
# 4.Improves Generalization

# %% [markdown]
# 19.  What are some real-world applications of ensemble techniques ?
#
# Ensemble techniques are widely used in real-world applications because they improve predictive accuracy, stability, and robustness compared to single models. Here are some key applications
# 1. Finance and Banking
# 2. Healthcare and Medicine
# 3. E-commerce and Marketing
# 4. Natural Language Processing (NLP)
# 5. Computer Vision and many  more

# %% [markdown]
# 20.  What is the difference between Bagging and Boosting?
#
# Bagging trains multiple models independently on random subsets of the data and combines their predictions by averaging (regression) or majority voting (classification). Its main goal is to reduce variance and prevent overfitting. Random Forest is a popular example of Bagging.
#
# Boosting trains models sequentially, where each new model tries to correct the mistakes of the previous ones. Predictions are combined in a weighted way. Its main goal is to reduce bias and make weak learners stronger. Examples include AdaBoost, Gradient Boosting, and XGBoost.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_iris()
X = data.data
y = data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Bagging Classifier
model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), # Changed base_estimator to estimator
    n_estimators=50,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 1.0

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load sample dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Bagging Regressor
model = BaggingRegressor(
    estimator=DecisionTreeRegressor(), # Changed base_estimator to estimator for scikit-learn v1.0+
    n_estimators=50,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Evaluate using MSE
mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error (MSE):", mse)
# Out:
# Mean Squared Error (MSE): 0.25787382250585034

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Load Breast Cancer dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Random Forest Classifier
model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Get feature importances
importances = model.feature_importances_

# Create a DataFrame for better display
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Print feature importance
print(importance_df)
# Out:
#                     Feature  Importance
# 7       mean concave points    0.141934
# 27     worst concave points    0.127136
# 23               worst area    0.118217
# 6            mean concavity    0.080557
# 20             worst radius    0.077975
# 22          worst perimeter    0.074292
# 2            mean perimeter    0.060092
# 3                 mean area    0.053810
# 26          worst concavity    0.041080
# 0               mean radius    0.032312
# 13               area error    0.029538
# 21            worst texture    0.018786
# 25        worst compactness    0.017539
# 10             radius error    0.016435
# 28           worst symmetry    0.012929
# 12          perimeter error    0.011770
# 24         worst smoothness    0.011769
# 1              mean texture    0.011064
# 5          mean compactness    0.009216
# 19  fractal dimension error    0.007135
# 29  worst fractal dimension    0.006924
# 4           mean smoothness    0.006223
# ...

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# Load dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ---------- Single Decision Tree ----------
tree_model = DecisionTreeRegressor(random_state=42)
tree_model.fit(X_train, y_train)
tree_preds = tree_model.predict(X_test)
tree_mse = mean_squared_error(y_test, tree_preds)

# ---------- Random Forest Regressor ----------
rf_model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)
rf_model.fit(X_train, y_train)
rf_preds = rf_model.predict(X_test)
rf_mse = mean_squared_error(y_test, rf_preds)

# Print comparison
print("Decision Tree MSE:", tree_mse)
print("Random Forest MSE:", rf_mse)
# Out:
# Decision Tree MSE: 0.5280096503174904
# Random Forest MSE: 0.25650512920799395

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split data (OOB scoring does not require test set, but we keep it for training stability)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Random Forest with OOB enabled
model = RandomForestClassifier(
    n_estimators=100,
    oob_score=True,
    bootstrap=True,   # required for OOB
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Print OOB Score
print("OOB Score:", model.oob_score_)
# Out:
# OOB Score: 0.9547738693467337

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_iris()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Bagging Classifier with SVM as base estimator
model = BaggingClassifier(
    estimator=SVC(), # Changed base_estimator to estimator
    n_estimators=30,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 1.0

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# List of number of trees to test
tree_counts = [10, 50, 100, 200, 300]

print("Comparing Random Forest performance:\n")

for n in tree_counts:
    model = RandomForestClassifier(
        n_estimators=n,
        random_state=42
    )

    # Train the model
    model.fit(X_train, y_train)

    # Predictions
    y_pred = model.predict(X_test)

    # Compute accuracy
    accuracy = accuracy_score(y_test, y_pred)

    print(f"{n} Trees → Accuracy: {accuracy:.4f}")
# Out:
# Comparing Random Forest performance:
#
# 10 Trees → Accuracy: 0.9649
# 50 Trees → Accuracy: 0.9708
# 100 Trees → Accuracy: 0.9708
# 200 Trees → Accuracy: 0.9708
# 300 Trees → Accuracy: 0.9708

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import roc_auc_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Bagging Classifier with Logistic Regression
model = BaggingClassifier(
    estimator=LogisticRegression(max_iter=1000), # Changed base_estimator to estimator
    n_estimators=20,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Predict probabilities for AUC
y_prob = model.predict_proba(X_test)[:, 1]

# Compute AUC
auc = roc_auc_score(y_test, y_prob)

print("AUC Score:", auc)

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# Load dataset
data = fetch_california_housing()
X = data.data
y = data.target
feature_names = data.feature_names

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Random Forest Regressor
model = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# Train the model
model.fit(X_train, y_train)

# Get feature importances
importances = model.feature_importances_

# Create DataFrame for better readability
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Print feature importances
print(importance_df)
# Out:
#       Feature  Importance
# 0      MedInc    0.526011
# 5    AveOccup    0.138220
# 7   Longitude    0.086124
# 6    Latitude    0.086086
# 1    HouseAge    0.054654
# 2    AveRooms    0.047188
# 4  Population    0.031722
# 3   AveBedrms    0.029995

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ---------- Bagging Classifier ----------
bagging_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), # Changed base_estimator to estimator
    n_estimators=100,
    random_state=42
)
bagging_model.fit(X_train, y_train)
bagging_pred = bagging_model.predict(X_test)
bagging_acc = accuracy_score(y_test, bagging_pred)

# ---------- Random Forest Classifier ----------
rf_model = RandomForestClassifier(
    n_estimators=100,
    random_state=42
)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)
rf_acc = accuracy_score(y_test, rf_pred)

# ---------- Print Comparison ----------
print("Bagging Classifier Accuracy:", bagging_acc)
print("Random Forest Accuracy:", rf_acc)
# Out:
# Bagging Classifier Accuracy: 0.9590643274853801
# Random Forest Accuracy: 0.9707602339181286

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Define Random Forest model
rf = RandomForestClassifier(random_state=42)

# Define hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt']
}

# Create GridSearchCV
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=5,           # 5-fold cross-validation
    n_jobs=-1,      # Use all processors
    scoring='accuracy'
)

# Fit GridSearchCV
grid_search.fit(X_train, y_train)

# Best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Predictions with best model
best_rf = grid_search.best_estimator_
y_pred = best_rf.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy with Best Parameters:", accuracy)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 405 fits failed out of a total of 810.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 405 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.12/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# List of number of base estimators to test
n_estimators_list = [5, 10, 20, 50, 100]

print("Bagging Regressor Performance:\n")

for n in n_estimators_list:
    # Create Bagging Regressor
    model = BaggingRegressor(
        estimator=DecisionTreeRegressor(),
        n_estimators=n,
        random_state=42
    )

    # Train model
    model.fit(X_train, y_train)

    # Predict
    y_pred = model.predict(X_test)

    # Evaluate using MSE
    mse = mean_squared_error(y_test, y_pred)

    print(f"{n} Base Estimators → MSE: {mse:.4f}")
# Out:
# Bagging Regressor Performance:
#
# 5 Base Estimators → MSE: 0.3168
# 10 Base Estimators → MSE: 0.2862
# 20 Base Estimators → MSE: 0.2693
# 50 Base Estimators → MSE: 0.2579
# 100 Base Estimators → MSE: 0.2568

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict on test set
y_pred = rf_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# Identify misclassified samples
misclassified_idx = [i for i in range(len(y_test)) if y_test[i] != y_pred[i]]

# Create DataFrame for misclassified samples
misclassified_df = pd.DataFrame(X_test[misclassified_idx], columns=feature_names)
misclassified_df['True Label'] = y_test[misclassified_idx]
misclassified_df['Predicted Label'] = y_pred[misclassified_idx]

# Display misclassified samples
print("\nMisclassified Samples:")
print(misclassified_df)
# Out:
# Test Accuracy: 0.9707602339181286
#
# Misclassified Samples:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        13.34         15.86           86.49      520.0          0.10780
# 1        13.80         15.79           90.43      584.1          0.10070
# 2        13.96         17.05           91.43      602.4          0.10960
# 3        14.48         21.46           94.25      648.2          0.09444
# 4        15.13         29.81           96.71      719.5          0.08320
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.15350         0.11690              0.06987         0.1942
# 1           0.12800         0.07789              0.05069         0.1662
# 2           0.12790         0.09789              0.05246         0.1908
# 3           0.09947         0.12040              0.04938         0.2075
# 4           0.04605         0.04686              0.02739         0.1852
#
# ...

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# ---------- Single Decision Tree ----------
tree_model = DecisionTreeClassifier(random_state=42)
tree_model.fit(X_train, y_train)
tree_pred = tree_model.predict(X_test)
tree_acc = accuracy_score(y_test, tree_pred)

# ---------- Bagging Classifier ----------
bagging_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), # Changed base_estimator to estimator
    n_estimators=50,
    random_state=42
)
bagging_model.fit(X_train, y_train)
bagging_pred = bagging_model.predict(X_test)
bagging_acc = accuracy_score(y_test, bagging_pred)

# ---------- Print Comparison ----------
print("Single Decision Tree Accuracy:", tree_acc)
print("Bagging Classifier Accuracy:", bagging_acc)
# Out:
# Single Decision Tree Accuracy: 0.9415204678362573
# Bagging Classifier Accuracy: 0.9590643274853801

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score
import matplotlib.pyplot as plt

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict on test set
y_pred = rf_model.predict(X_test)

# Calculate accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Visualize confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data.target_names)
disp.plot(cmap=plt.cm.Blues)
plt.title("Random Forest Confusion Matrix")
plt.show()
# Out:
# Test Accuracy: 0.9707602339181286

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Define base learners
base_learners = [
    ('dt', DecisionTreeClassifier(random_state=42)),
    ('svc', SVC(probability=True, random_state=42)),
    ('lr', LogisticRegression(max_iter=1000, random_state=42))
]

# Define Stacking Classifier (using Logistic Regression as final estimator)
stack_model = StackingClassifier(
    estimators=base_learners,
    final_estimator=LogisticRegression(),
    cv=5
)

# Train Stacking Classifier
stack_model.fit(X_train, y_train)
stack_pred = stack_model.predict(X_test)
stack_acc = accuracy_score(y_test, stack_pred)
print("Stacking Classifier Accuracy:", stack_acc)

# ---------- Compare with individual base models ----------
for name, model in base_learners:
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    acc = accuracy_score(y_test, pred)
    print(f"{name} Accuracy: {acc}")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
import pandas as pd

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target
feature_names = data.feature_names

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Get feature importances
importances = rf_model.feature_importances_

# Create DataFrame for better readability
importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
}).sort_values(by='Importance', ascending=False)

# Print top 5 most important features
print("Top 5 Most Important Features:")
print(importance_df.head(5))
# Out:
# Top 5 Most Important Features:
#                  Feature  Importance
# 7    mean concave points    0.141934
# 27  worst concave points    0.127136
# 23            worst area    0.118217
# 6         mean concavity    0.080557
# 20          worst radius    0.077975

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Create Bagging Classifier
bagging_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), # Changed base_estimator to estimator
    n_estimators=50,
    random_state=42
)

# Train the model
bagging_model.fit(X_train, y_train)

# Predictions
y_pred = bagging_model.predict(X_test)

# Overall accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Precision, Recall, F1-score
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=data.target_names))
# Out:
# Accuracy: 0.9590643274853801
#
# Classification Report:
#               precision    recall  f1-score   support
#
#    malignant       0.95      0.94      0.94        63
#       benign       0.96      0.97      0.97       108
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# List of max_depth values to test
max_depth_values = [None, 2, 4, 6, 8, 10, 15, 20]

# Store accuracies
accuracies = []

for depth in max_depth_values:
    model = RandomForestClassifier(
        n_estimators=100,
        max_depth=depth,
        random_state=42
    )
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    print(f"max_depth={depth} → Accuracy: {acc:.4f}")

# Visualize
plt.figure(figsize=(8,5))
plt.plot([str(d) for d in max_depth_values], accuracies, marker='o')
plt.xlabel('max_depth')
plt.ylabel('Accuracy')
plt.title('Effect of max_depth on Random Forest Accuracy')
plt.grid(True)
plt.show()
# Out:
# max_depth=None → Accuracy: 0.9708
# max_depth=2 → Accuracy: 0.9532
# max_depth=4 → Accuracy: 0.9708
# max_depth=6 → Accuracy: 0.9649
# max_depth=8 → Accuracy: 0.9708
# max_depth=10 → Accuracy: 0.9708
# max_depth=15 → Accuracy: 0.9708
# max_depth=20 → Accuracy: 0.9708

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import BaggingRegressor
from sklearn.metrics import mean_squared_error

# Load dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Define base estimators
base_estimators = {
    "Decision Tree": DecisionTreeRegressor(),
    "K-Neighbors": KNeighborsRegressor()
}

# Train Bagging Regressors and evaluate
print("Bagging Regressor Performance:\n")
for name, base in base_estimators.items():
    model = BaggingRegressor(
        estimator=base, # Changed base_estimator to estimator
        n_estimators=50,
        random_state=42
    )
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    print(f"{name} Base Estimator → MSE: {mse:.4f}")
# Out:
# Bagging Regressor Performance:
#
# Decision Tree Base Estimator → MSE: 0.2579
# K-Neighbors Base Estimator → MSE: 1.1021

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict probabilities for positive class
y_prob = rf_model.predict_proba(X_test)[:, 1]

# Compute ROC-AUC score
roc_auc = roc_auc_score(y_test, y_prob)
print("ROC-AUC Score:", roc_auc)
# Out:
# ROC-AUC Score: 0.9968400940623163

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
import numpy as np

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Create Bagging Classifier
bagging_model = BaggingClassifier(
    estimator=DecisionTreeClassifier(), # Changed base_estimator to estimator
    n_estimators=50,
    random_state=42
)

# Define cross-validation strategy (Stratified K-Fold)
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Evaluate using cross-validation
cv_scores = cross_val_score(bagging_model, X, y, cv=cv, scoring='accuracy')

# Print results
print("Cross-Validation Accuracy Scores:", cv_scores)
print("Mean CV Accuracy:", np.mean(cv_scores))
print("Standard Deviation:", np.std(cv_scores))
# Out:
# Cross-Validation Accuracy Scores: [0.96491228 0.92982456 0.96491228 0.96491228 0.96460177]
# Mean CV Accuracy: 0.9578326346840551
# Standard Deviation: 0.0140045530012473

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve, average_precision_score
import matplotlib.pyplot as plt

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Train Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict probabilities for positive class
y_prob = rf_model.predict_proba(X_test)[:, 1]

# Compute precision and recall
precision, recall, thresholds = precision_recall_curve(y_test, y_prob)

# Compute average precision score
avg_precision = average_precision_score(y_test, y_prob)
print("Average Precision Score:", avg_precision)

# Plot Precision-Recall curve
plt.figure(figsize=(8,6))
plt.plot(recall, precision, marker='.', label=f'Random Forest (AP={avg_precision:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Average Precision Score: 0.9981193532697757

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load dataset
data = load_breast_cancer()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Define base learners
base_learners = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=42)),
    ('lr', LogisticRegression(max_iter=1000, random_state=42))
]

# Define Stacking Classifier using Logistic Regression as final estimator
stack_model = StackingClassifier(
    estimators=base_learners,
    final_estimator=LogisticRegression(),
    cv=5
)

# Train Stacking Classifier
stack_model.fit(X_train, y_train)
stack_pred = stack_model.predict(X_test)
stack_acc = accuracy_score(y_test, stack_pred)
print("Stacking Classifier Accuracy:", stack_acc)

# ---------- Compare with individual base models ----------
for name, model in base_learners:
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    acc = accuracy_score(y_test, pred)
    print(f"{name} Accuracy: {acc}")
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error

# Load dataset
data = fetch_california_housing()
X = data.data
y = data.target

# Split dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# Different bootstrap sampling options to test
bootstrap_options = [True, False]  # True: with replacement, False: without replacement

print("Bagging Regressor Performance with Different Bootstrap Sampling:\n")

for bootstrap in bootstrap_options:
    model = BaggingRegressor(
        estimator=DecisionTreeRegressor(), # Changed base_estimator to estimator
        n_estimators=50,
        bootstrap=bootstrap,
        random_state=42
    )
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    mse = mean_squared_error(y_test, y_pred)
    method = "With Replacement" if bootstrap else "Without Replacement"
    print(f"{method} → MSE: {mse:.4f}")
# Out:
# Bagging Regressor Performance with Different Bootstrap Sampling:
#
# With Replacement → MSE: 0.2579
# Without Replacement → MSE: 0.4967
